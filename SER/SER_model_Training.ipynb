# %%
import pandas as pd
import numpy as np
import os
import sys
from tqdm.notebook import tqdm, trange

# librosa is a Python library for analyzing audio and music. It will be used to extract the data from the audio files
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from joblib import dump, load

# to play the audio files
from IPython.display import Audio

import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# # Data Preparation

# %%
# Paths for data.
Ravdess = "D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/Ravdess/"
#Crema = "D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/CREMA-D/AudioWAV/"
Tess = "D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS/"
Savee = "D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/savee/AudioData/"

# %%
ravdess_directory_list = os.listdir(Ravdess)

file_emotion = []
file_path = []
for dir in ravdess_directory_list:
    # as their are 20 different actors in our previous directory we need to extract files for each actor.
    actor = os.listdir(Ravdess + dir)
    for file in actor:
        part = file.split('.')[0]
        part = part.split('-')
        # third part in each file represents the emotion associated to that file.
        file_emotion.append(int(part[2]))
        file_path.append(Ravdess + dir + '/' + file)
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Ravdess_df = pd.concat([emotion_df, path_df], axis=1)

# changing integers to actual emotions.
Ravdess_df.Emotions.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
Ravdess_df.head()
# Out:
#   Emotions                                               Path
# 0  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 1  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 2  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 3  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 4     calm  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...

# %% [markdown]
# crema_directory_list = os.listdir(Crema)
#
# file_emotion = []
# file_path = []
#
# for file in crema_directory_list:
#     # storing file paths
#     file_path.append(Crema + file)
#     # storing file emotions
#     part=file.split('_')
#     if part[2] == 'SAD':
#         file_emotion.append('sad')
#     elif part[2] == 'ANG':
#         file_emotion.append('angry')
#     elif part[2] == 'DIS':
#         file_emotion.append('disgust')
#     elif part[2] == 'FEA':
#         file_emotion.append('fear')
#     elif part[2] == 'HAP':
#         file_emotion.append('happy')
#     elif part[2] == 'NEU':
#         file_emotion.append('neutral')
#     else:
#         file_emotion.append('Unknown')
#
# # dataframe for emotion of files
# emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])
#
# # dataframe for path of files.
# path_df = pd.DataFrame(file_path, columns=['Path'])
# Crema_df = pd.concat([emotion_df, path_df], axis=1)
# Crema_df.head()

# %%
tess_directory_list = os.listdir(Tess)

file_emotion = []
file_path = []

for file in tess_directory_list:
    part = file.split('.')[0]
    part = part.split('_')[2]
    if part=='ps':
        file_emotion.append('surprise')
    else:
        file_emotion.append(part)
    file_path.append(Tess + '/' + file)
    print(Tess + '/' + file)
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Tess_df = pd.concat([emotion_df, path_df], axis=1)
Tess_df.head()
# Out:
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_back_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_back_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_back_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_back_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_back_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_back_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_back_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bar_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bar_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bar_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bar_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bar_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bar_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bar_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_base_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_base_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_base_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_base_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_base_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_base_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_base_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bath_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bath_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bath_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bath_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bath_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bath_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bath_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bean_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bean_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bean_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bean_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bean_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bean_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bean_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_beg_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_beg_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_beg_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_beg_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_beg_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_beg_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_beg_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bite_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bite_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bite_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bite_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bite_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bite_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bite_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_boat_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_boat_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_boat_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_boat_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_boat_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_boat_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_boat_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bone_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bone_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bone_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bone_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bone_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bone_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bone_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_book_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_book_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_book_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_book_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_book_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_book_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_book_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bought_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bought_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bought_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bought_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bought_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bought_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_bought_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_burn_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_burn_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_burn_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_burn_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_burn_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_burn_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_burn_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cab_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cab_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cab_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cab_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cab_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cab_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cab_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_calm_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_calm_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_calm_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_calm_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_calm_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_calm_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_calm_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_came_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_came_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_came_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_came_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_came_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_came_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_came_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cause_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cause_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cause_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cause_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cause_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cause_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cause_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chain_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chain_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chain_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chain_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chain_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chain_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chain_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chair_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chair_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chair_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chair_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chair_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chair_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chair_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chalk_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chalk_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chalk_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chalk_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chalk_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chalk_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chalk_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chat_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chat_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chat_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chat_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chat_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chat_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chat_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_check_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_check_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_check_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_check_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_check_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_check_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_check_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cheek_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cheek_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cheek_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cheek_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cheek_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cheek_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cheek_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chief_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chief_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chief_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chief_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chief_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chief_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_chief_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_choice_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_choice_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_choice_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_choice_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_choice_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_choice_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_choice_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cool_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cool_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cool_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cool_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cool_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cool_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_cool_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dab_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dab_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dab_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dab_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dab_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dab_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dab_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_date_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_date_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_date_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_date_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_date_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_date_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_date_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dead_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dead_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dead_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dead_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dead_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dead_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dead_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_death_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_death_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_death_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_death_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_death_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_death_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_death_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_deep_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_deep_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_deep_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_deep_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_deep_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_deep_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_deep_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dime_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dime_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dime_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dime_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dime_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dime_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dime_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dip_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dip_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dip_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dip_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dip_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dip_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dip_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_ditch_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_ditch_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_ditch_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_ditch_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_ditch_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_ditch_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_ditch_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dodge_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dodge_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dodge_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dodge_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dodge_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dodge_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dodge_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dog_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dog_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dog_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dog_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dog_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dog_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_dog_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_doll_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_doll_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_doll_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_doll_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_doll_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_doll_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_doll_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_door_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_door_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_door_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_door_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_door_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_door_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_door_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fail_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fail_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fail_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fail_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fail_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fail_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fail_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fall_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fall_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fall_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fall_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fall_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fall_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fall_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_far_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_far_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_far_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_far_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_far_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_far_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_far_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fat_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fat_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fat_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fat_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fat_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fat_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fat_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fit_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fit_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fit_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fit_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fit_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fit_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_fit_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_five_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_five_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_five_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_five_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_five_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_five_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_five_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_food_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_food_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_food_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_food_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_food_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_food_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_food_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gap_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gap_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gap_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gap_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gap_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gap_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gap_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gas_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gas_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gas_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gas_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gas_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gas_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gas_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gaze_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gaze_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gaze_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gaze_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gaze_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gaze_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gaze_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_germ_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_germ_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_germ_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_germ_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_germ_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_germ_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_germ_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_get_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_get_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_get_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_get_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_get_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_get_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_get_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gin_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gin_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gin_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gin_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gin_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gin_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gin_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_goal_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_goal_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_goal_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_goal_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_goal_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_goal_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_goal_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_good_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_good_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_good_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_good_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_good_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_good_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_good_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_goose_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_goose_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_goose_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_goose_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_goose_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_goose_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_goose_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gun_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gun_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gun_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gun_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gun_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gun_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_gun_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_half_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_half_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_half_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_half_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_half_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_half_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_half_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hall_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hall_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hall_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hall_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hall_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hall_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hall_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hash_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hash_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hash_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hash_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hash_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hash_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hash_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hate_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hate_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hate_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hate_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hate_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hate_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hate_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_have_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_have_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_have_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_have_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_have_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_have_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_have_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_haze_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_haze_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_haze_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_haze_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_haze_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_haze_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_haze_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hire_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hire_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hire_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hire_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hire_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hire_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hire_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hit_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hit_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hit_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hit_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hit_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hit_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hit_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hole_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hole_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hole_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hole_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hole_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hole_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hole_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_home_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_home_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_home_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_home_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_home_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_home_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_home_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hurl_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hurl_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hurl_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hurl_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hurl_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hurl_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hurl_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hush_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hush_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hush_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hush_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hush_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hush_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_hush_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jail_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jail_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jail_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jail_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jail_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jail_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jail_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jar_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jar_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jar_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jar_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jar_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jar_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jar_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_join_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_join_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_join_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_join_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_join_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_join_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_join_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_judge_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_judge_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_judge_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_judge_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_judge_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_judge_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_judge_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jug_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jug_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jug_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jug_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jug_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//OAF_jug_ps.wav
# ...
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_tool_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_tool_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_tool_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_tool_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_tool_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_tool_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_tool_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_tough_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_tough_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_tough_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_tough_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_tough_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_tough_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_tough_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_turn_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_turn_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_turn_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_turn_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_turn_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_turn_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_turn_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_vine_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_vine_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_vine_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_vine_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_vine_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_vine_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_vine_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_voice_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_voice_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_voice_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_voice_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_voice_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_voice_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_voice_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_void_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_void_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_void_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_void_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_void_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_void_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_void_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_vote_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_vote_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_vote_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_vote_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_vote_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_vote_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_vote_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wag_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wag_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wag_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wag_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wag_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wag_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wag_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_walk_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_walk_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_walk_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_walk_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_walk_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_walk_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_walk_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wash_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wash_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wash_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wash_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wash_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wash_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wash_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_week_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_week_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_week_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_week_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_week_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_week_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_week_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wheat_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wheat_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wheat_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wheat_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wheat_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wheat_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wheat_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_when_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_when_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_when_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_when_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_when_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_when_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_when_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_which_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_which_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_which_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_which_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_which_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_which_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_which_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_whip_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_whip_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_whip_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_whip_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_whip_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_whip_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_whip_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_white_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_white_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_white_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_white_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_white_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_white_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_white_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wife_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wife_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wife_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wife_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wife_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wife_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wife_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wire_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wire_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wire_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wire_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wire_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wire_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_wire_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_witch_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_witch_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_witch_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_witch_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_witch_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_witch_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_witch_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_yearn_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_yearn_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_yearn_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_yearn_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_yearn_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_yearn_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_yearn_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_yes_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_yes_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_yes_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_yes_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_yes_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_yes_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_yes_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_young_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_young_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_young_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_young_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_young_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_young_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_young_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_youth_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_youth_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_youth_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_youth_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_youth_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_youth_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction2/SER/data/TESS//YAF_youth_sad.wav
#   Emotions                                               Path
# 0    angry  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 1  disgust  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 2     fear  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 3    happy  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 4  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...

# %%
savee_directory_list = os.listdir(Savee)

file_emotion = []
file_path = []

for dir in savee_directory_list:
    directories = os.listdir(Savee + dir)
    for file in directories:
        file_path.append(Savee + dir + '/' + file)
        #part = file.split('_')[1]
        ele = file[:-6]
        if ele=='a':
            file_emotion.append('angry')
        elif ele=='d':
            file_emotion.append('disgust')
        elif ele=='f':
            file_emotion.append('fear')
        elif ele=='h':
            file_emotion.append('happy')
        elif ele=='n':
            file_emotion.append('neutral')
        elif ele=='sa':
            file_emotion.append('sad')
        else:
            file_emotion.append('surprise')
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Savee_df = pd.concat([emotion_df, path_df], axis=1)
Savee_df.head()
# Out:
#   Emotions                                               Path
# 0    angry  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 1    angry  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 2    angry  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 3    angry  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 4    angry  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...

# %%
# creating Dataframe using all the 4 dataframes we created so far.
data_path = pd.concat([Ravdess_df, Savee_df, Tess_df], axis = 0) #,Crema_df
data_path.to_csv("data_path.csv",index=False)
data_path.head()
# Out:
#   Emotions                                               Path
# 0  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 1  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 2  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 3  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 4     calm  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...

# %% [markdown]
# # Data Visualisation and Exploration

# %%
plt.title('Count of Emotions', size=16)
sns.countplot(data_path.Emotions)
plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
def create_waveplot(data, sr, e):
    plt.figure(figsize=(10, 3))
    plt.title('Waveplot for audio with {} emotion'.format(e), size=15)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def create_spectrogram(data, sr, e):
    # stft function converts the data into short term fourier transform
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(12, 3))
    plt.title('Spectrogram for audio with {} emotion'.format(e), size=15)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')   
    #librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar()

# %% [markdown]
# # Data Augmentation

# %%
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate)

def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)

def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)

# taking any example and checking for techniques.
path = np.array(data_path.Path)[1]
data, sample_rate = librosa.load(path)

# %% [markdown]
# # Feature Extraction

# %%
def extract_features(data):
    # ZCR
    result = np.array([])
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    result=np.hstack((result, zcr)) # stacking horizontally

    # Chroma_stft
    stft = np.abs(librosa.stft(data))
    chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
    result = np.hstack((result, chroma_stft)) # stacking horizontally

    # MFCC
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mfcc)) # stacking horizontally

    # Root Mean Square Value
    rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
    result = np.hstack((result, rms)) # stacking horizontally

    # MelSpectogram
    mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mel)) # stacking horizontally
    
    return result

def get_features(path):
    # duration and offset are used to take care of the no audio in start and the ending of each audio files as seen above.
    data, sample_rate = librosa.load(path)
    
    # without augmentation
    res1 = extract_features(data)
    result = np.array(res1)
    
    # data with noise
    noise_data = noise(data)
    res2 = extract_features(noise_data)
    result = np.vstack((result, res2)) # stacking vertically
    
    # data with stretching and pitching
    new_data = stretch(data)
    data_stretch_pitch = pitch(new_data, sample_rate)
    res3 = extract_features(data_stretch_pitch)
    result = np.vstack((result, res3)) # stacking vertically
    
    return result

# %%
X, Y = [], []
for path, emotion in tqdm(zip(data_path.Path, data_path.Emotions), total=len(data_path.Path)):
    if emotion in ['angry','happy','fear','sad']:      #filter emotions
        feature = get_features(path)
        for ele in feature:
            X.append(ele)
            # appending emotion 3 times as we have made 3 augmentation techniques on each audio file.
            Y.append(emotion)
# Out:
#   0%|          | 0/4720 [00:00<?, ?it/s]

# %%
len(X), len(Y), data_path.Path.shape
# Out:
# (7824, 7824, (4720,))

# %%
Features = pd.DataFrame(X)
Features['labels'] = Y
Features.to_csv('features.csv', index=False)
Features.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.268639  0.707646  0.720438  0.709807  0.724831  0.764116  0.729821
# 1  0.313187  0.802962  0.811305  0.798262  0.829351  0.818667  0.675278
# 2  0.184032  0.672623  0.665721  0.710286  0.722913  0.727651  0.763631
# 3  0.177728  0.698396  0.694189  0.673926  0.702338  0.699964  0.723477
# 4  0.347448  0.807989  0.809523  0.834870  0.858393  0.830839  0.738735
#
#           7         8         9  ...           153           154  \
# 0  0.713823  0.761184  0.778403  ...  1.899556e-16  1.910081e-16
# 1  0.652811  0.702250  0.731037  ...  5.180037e-06  5.038315e-06
# 2  0.758967  0.706407  0.721552  ...  1.580588e-12  1.547995e-12
# 3  0.700252  0.743828  0.765305  ...  3.159090e-16  2.804944e-16
# 4  0.695795  0.724346  0.740383  ...  1.594222e-04  1.599906e-04
#
#             155           156           157           158           159  \
# 0  2.036723e-16  2.042289e-16  1.910965e-16  2.005536e-16  1.924764e-16
# 1  5.365116e-06  5.142757e-06  5.086410e-06  5.192430e-06  5.238402e-06
# 2  1.443010e-12  1.364618e-12  1.221601e-12  1.264466e-12  1.222045e-12
# 3  2.486411e-16  2.664748e-16  2.487334e-16  2.565823e-16  2.585303e-16
# 4  1.689895e-04  1.667262e-04  1.696795e-04  1.568110e-04  1.574424e-04
#
#             160           161  labels
# 0  1.756457e-16  1.834831e-16   happy
# 1  5.293699e-06  5.302766e-06   happy
# 2  1.132658e-12  1.146593e-12   happy
# 3  2.494821e-16  2.572587e-16   happy
# 4  1.605150e-04  1.749457e-04   happy
#
# [5 rows x 163 columns]

# %% [markdown]
# # Data Preparation

# %%
Features = pd.read_csv('features.csv')
X = Features.iloc[: ,:-1].values
Y = Features['labels'].values

# %%
# As this is a multiclass classification problem onehotencoding our Y.
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
# splitting data
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((5868, 162), (5868, 4), (1956, 162), (1956, 4))

# %%
# scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape

dump(scaler, 'std_scaler.bin', compress=True)
# Out:
# ['std_scaler.bin']

# %%
# making our data compatible to model.
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((5868, 162, 1), (5868, 4), (1956, 162, 1), (1956, 4))

# %% [markdown]
# # Modelling

# %%
model = Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=4, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 162, 256)          1536
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 81, 256)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 81, 256)           327936
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 41, 256)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 41, 128)           163968
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 21, 128)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 21, 128)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 21, 64)            41024
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 11, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 704)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                22560
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 557,156
# Trainable params: 557,156
# Non-trainable params: 0
# _________________________________________________________________

# %%
########### only to test settings!########################
def cnn2(X_train, y_train):
    model = Sequential()
    model.add(Conv1D(256, 4, padding='same', input_shape=(X_train.shape[1],1)))  # X_train.shape[1] = No. of Columns
    model.add(Activation('relu'))
    model.add(Conv1D(256, 4, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(8)))
    model.add(Conv1D(128, 4, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 4, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 4, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 4, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(8)))
    model.add(Conv1D(64, 4, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 4, padding='same'))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(y_train.shape[1])) # Target class number
    model.add(Activation('softmax'))
    model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])
    return model

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)
history=model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), callbacks=[rlrp])
# Out:
# Epoch 1/50
# 92/92 [==============================] - 9s 99ms/step - loss: 1.0985 - accuracy: 0.5039 - val_loss: 0.7526 - val_accuracy: 0.7040
# Epoch 2/50
# 92/92 [==============================] - 10s 111ms/step - loss: 0.7341 - accuracy: 0.6922 - val_loss: 0.6169 - val_accuracy: 0.7485
# Epoch 3/50
# 92/92 [==============================] - 10s 104ms/step - loss: 0.6205 - accuracy: 0.7422 - val_loss: 0.5446 - val_accuracy: 0.7776
# Epoch 4/50
# 92/92 [==============================] - 9s 102ms/step - loss: 0.5527 - accuracy: 0.7630 - val_loss: 0.5246 - val_accuracy: 0.7812
# Epoch 5/50
# 92/92 [==============================] - 9s 103ms/step - loss: 0.5128 - accuracy: 0.7747 - val_loss: 0.4991 - val_accuracy: 0.7781
# Epoch 6/50
# 92/92 [==============================] - 10s 104ms/step - loss: 0.4878 - accuracy: 0.7853 - val_loss: 0.4545 - val_accuracy: 0.8006
# Epoch 7/50
# 92/92 [==============================] - 10s 103ms/step - loss: 0.4820 - accuracy: 0.7899 - val_loss: 0.4189 - val_accuracy: 0.8231
# Epoch 8/50
# 92/92 [==============================] - 10s 110ms/step - loss: 0.4521 - accuracy: 0.8011 - val_loss: 0.4221 - val_accuracy: 0.8011
# Epoch 9/50
# 92/92 [==============================] - 9s 103ms/step - loss: 0.4362 - accuracy: 0.8108 - val_loss: 0.4095 - val_accuracy: 0.8303
# Epoch 10/50
# 92/92 [==============================] - 9s 103ms/step - loss: 0.4224 - accuracy: 0.8139 - val_loss: 0.4231 - val_accuracy: 0.8308
# Epoch 11/50
# 92/92 [==============================] - 10s 105ms/step - loss: 0.4191 - accuracy: 0.8194 - val_loss: 0.4034 - val_accuracy: 0.8303
# Epoch 12/50
# 92/92 [==============================] - 9s 95ms/step - loss: 0.4059 - accuracy: 0.8241 - val_loss: 0.4421 - val_accuracy: 0.7960
# Epoch 13/50
# 92/92 [==============================] - 10s 105ms/step - loss: 0.3899 - accuracy: 0.8333 - val_loss: 0.3811 - val_accuracy: 0.8400
# Epoch 14/50
# 92/92 [==============================] - 9s 98ms/step - loss: 0.3820 - accuracy: 0.8335 - val_loss: 0.3964 - val_accuracy: 0.8384
# Epoch 15/50
# 92/92 [==============================] - 9s 97ms/step - loss: 0.3515 - accuracy: 0.8516 - val_loss: 0.3785 - val_accuracy: 0.8349
# Epoch 16/50
# 92/92 [==============================] - 9s 99ms/step - loss: 0.3680 - accuracy: 0.8374 - val_loss: 0.3682 - val_accuracy: 0.8451
# Epoch 17/50
# 92/92 [==============================] - 9s 95ms/step - loss: 0.3421 - accuracy: 0.8540 - val_loss: 0.3573 - val_accuracy: 0.8553
# Epoch 18/50
# 92/92 [==============================] - 9s 101ms/step - loss: 0.3266 - accuracy: 0.8611 - val_loss: 0.3865 - val_accuracy: 0.8451
# Epoch 19/50
# 92/92 [==============================] - 9s 98ms/step - loss: 0.3269 - accuracy: 0.8621 - val_loss: 0.3677 - val_accuracy: 0.8390
# Epoch 20/50
# 92/92 [==============================] - 9s 103ms/step - loss: 0.3107 - accuracy: 0.8696 - val_loss: 0.3788 - val_accuracy: 0.8456
# Epoch 21/50
# 92/92 [==============================] - 9s 103ms/step - loss: 0.2967 - accuracy: 0.8751 - val_loss: 0.3997 - val_accuracy: 0.8425
# Epoch 22/50
# 92/92 [==============================] - 9s 98ms/step - loss: 0.2994 - accuracy: 0.8771 - val_loss: 0.3662 - val_accuracy: 0.8533
# Epoch 23/50
# 92/92 [==============================] - 10s 110ms/step - loss: 0.3048 - accuracy: 0.8739 - val_loss: 0.3556 - val_accuracy: 0.8599
# Epoch 24/50
# 92/92 [==============================] - 10s 106ms/step - loss: 0.2537 - accuracy: 0.8896 - val_loss: 0.3307 - val_accuracy: 0.8696
# Epoch 25/50
# 92/92 [==============================] - 9s 96ms/step - loss: 0.2290 - accuracy: 0.9039 - val_loss: 0.3321 - val_accuracy: 0.8650
# Epoch 26/50
# 92/92 [==============================] - 9s 97ms/step - loss: 0.2269 - accuracy: 0.9059 - val_loss: 0.3248 - val_accuracy: 0.8768
# Epoch 27/50
# 92/92 [==============================] - 9s 95ms/step - loss: 0.2131 - accuracy: 0.9155 - val_loss: 0.3270 - val_accuracy: 0.8712
# Epoch 28/50
# 92/92 [==============================] - 9s 102ms/step - loss: 0.2049 - accuracy: 0.9199 - val_loss: 0.3218 - val_accuracy: 0.8793
# Epoch 29/50
# 92/92 [==============================] - 9s 94ms/step - loss: 0.2034 - accuracy: 0.9151 - val_loss: 0.3783 - val_accuracy: 0.8732
# Epoch 30/50
# 92/92 [==============================] - 9s 103ms/step - loss: 0.1933 - accuracy: 0.9248 - val_loss: 0.3173 - val_accuracy: 0.8814
# Epoch 31/50
# 92/92 [==============================] - 9s 94ms/step - loss: 0.1843 - accuracy: 0.9248 - val_loss: 0.3241 - val_accuracy: 0.8804
# Epoch 32/50
# 92/92 [==============================] - 9s 96ms/step - loss: 0.1649 - accuracy: 0.9352 - val_loss: 0.3378 - val_accuracy: 0.8773
# Epoch 33/50
# 92/92 [==============================] - 9s 96ms/step - loss: 0.1746 - accuracy: 0.9277 - val_loss: 0.3263 - val_accuracy: 0.8865
# Epoch 34/50
# 92/92 [==============================] - 9s 96ms/step - loss: 0.1704 - accuracy: 0.9339 - val_loss: 0.3450 - val_accuracy: 0.8778
# Epoch 35/50
# 92/92 [==============================] - 9s 103ms/step - loss: 0.1428 - accuracy: 0.9444 - val_loss: 0.3236 - val_accuracy: 0.8793
# Epoch 36/50
# 92/92 [==============================] - 9s 96ms/step - loss: 0.1348 - accuracy: 0.9480 - val_loss: 0.3468 - val_accuracy: 0.8829
# Epoch 37/50
# 92/92 [==============================] - 9s 103ms/step - loss: 0.1321 - accuracy: 0.9504 - val_loss: 0.3250 - val_accuracy: 0.8855
# Epoch 38/50
# 92/92 [==============================] - 9s 97ms/step - loss: 0.1256 - accuracy: 0.9509 - val_loss: 0.3315 - val_accuracy: 0.8931
# Epoch 39/50
# 92/92 [==============================] - 9s 102ms/step - loss: 0.1263 - accuracy: 0.9514 - val_loss: 0.3429 - val_accuracy: 0.8911
# Epoch 40/50
# 92/92 [==============================] - 9s 97ms/step - loss: 0.1211 - accuracy: 0.9552 - val_loss: 0.3301 - val_accuracy: 0.8911
# Epoch 41/50
# 92/92 [==============================] - 9s 98ms/step - loss: 0.1180 - accuracy: 0.9550 - val_loss: 0.3397 - val_accuracy: 0.8988
# Epoch 42/50
# 92/92 [==============================] - 9s 98ms/step - loss: 0.1052 - accuracy: 0.9600 - val_loss: 0.3555 - val_accuracy: 0.8952
# Epoch 43/50
# 92/92 [==============================] - 9s 95ms/step - loss: 0.1122 - accuracy: 0.9571 - val_loss: 0.3476 - val_accuracy: 0.8952
# Epoch 44/50
# 92/92 [==============================] - 9s 98ms/step - loss: 0.0989 - accuracy: 0.9651 - val_loss: 0.3693 - val_accuracy: 0.8962
# Epoch 45/50
# 92/92 [==============================] - 9s 95ms/step - loss: 0.1024 - accuracy: 0.9617 - val_loss: 0.3487 - val_accuracy: 0.8993
# Epoch 46/50
# 92/92 [==============================] - 9s 99ms/step - loss: 0.0920 - accuracy: 0.9681 - val_loss: 0.3376 - val_accuracy: 0.9039
# Epoch 47/50
# 92/92 [==============================] - 9s 97ms/step - loss: 0.0940 - accuracy: 0.9671 - val_loss: 0.3607 - val_accuracy: 0.8916
# Epoch 48/50
# 92/92 [==============================] - 9s 97ms/step - loss: 0.0941 - accuracy: 0.9669 - val_loss: 0.3509 - val_accuracy: 0.8983
# Epoch 49/50
# 92/92 [==============================] - 9s 99ms/step - loss: 0.0795 - accuracy: 0.9719 - val_loss: 0.3560 - val_accuracy: 0.9008
# Epoch 50/50
# 92/92 [==============================] - 9s 96ms/step - loss: 0.0834 - accuracy: 0.9688 - val_loss: 0.3469 - val_accuracy: 0.9034

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(50)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 62/62 [==============================] - 1s 14ms/step - loss: 0.3469 - accuracy: 0.9034
# Accuracy of our model on test data :  90.33742547035217 %

# %%
# predicting on test data.
pred_test = model.predict(x_test)

y_pred = encoder.inverse_transform(pred_test)
y_test = encoder.inverse_transform(y_test)

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0              sad           sad
# 1             fear          fear
# 2             fear          fear
# 3            happy         happy
# 4             fear          fear
# 5             fear          fear
# 6            angry         angry
# 7            happy          fear
# 8            happy         happy
# 9            angry         angry

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
model.save('SER_model_all8_without_CREMA.h5')
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.95      0.91      0.93       442
#         fear       0.89      0.90      0.89       518
#        happy       0.87      0.86      0.86       481
#          sad       0.91      0.95      0.93       515
#
#     accuracy                           0.90      1956
#    macro avg       0.90      0.90      0.90      1956
# weighted avg       0.90      0.90      0.90      1956

# %% [markdown]
# --------------------------------------------------------------------------------------
# Use the part below to test the trained model.

# %%
#PREPARE
import speech_recognition as sr
import librosa as lb
from joblib import dump, load
scaler = load('std_scaler.bin')  #load pretrained SciKit StandardScaler
r = sr.Recognizer()
model = keras.models.load_model('SER_model_all8_without_CREMA.h5')

# %%
#for i in range(5):
#    with sr.Microphone() as source:
#        print("Say something!")
#        audio = r.listen(source)
#    with open("microphone-results.wav", "wb") as f:
#        f.write(audio.get_wav_data())
    
#X, sample_rate = lb.load('D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/Ravdess/Actor_03/03-01-01-01-01-01-03.wav')
#plt.figure(figsize=(8, 4))
#lb.display.waveshow(X, sr=sample_rate)
#plt.title('Waveplot - Male Neutral')
#plt.show()


x_audio = get_features('D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/savee/AudioData/JE/h08.wav')
x_audio = scaler.transform(x_audio)
x_audio = np.expand_dims(x_audio, axis=2)
pred = model.predict(x_audio)
#pred = encoder.inverse_transform(pred)
#print(np.argmax(pred[0]))
j=[]
for i in range(3):
    j.append(np.argmax(pred[i]))
counts = np.bincount(j)
print(np.argmax(counts))
#0:angry, 1:fear, 2:happy, 3:sad
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\.conda\envs\myenv\lib\site-packages\librosa\core\audio.py:164, in load(path, sr, mono, offset, duration, dtype, res_type)
#     163 try:
# --> 164     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     166 except RuntimeError as exc:
#     167     # If soundfile failed, try audioread instead
#
# File ~\.conda\envs\myenv\lib\site-packages\librosa\core\audio.py:195, in __soundfile_load(path, offset, duration, dtype)
#     193 else:
#     194     # Otherwise, create the soundfile object
# --> 195     context = sf.SoundFile(path)
#     197 with context as sf_desc:
#
# File ~\.conda\envs\myenv\lib\site-packages\soundfile.py:629, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     627 self._info = _create_info_struct(file, mode, samplerate, channels,
#     628                                  format, subtype, endian)
# --> 629 self._file = self._open(file, mode_int, closefd)
#     630 if set(mode).issuperset('r+') and self.seekable():
#     631     # Move write position to 0 (like in Python file objects)
#
# File ~\.conda\envs\myenv\lib\site-packages\soundfile.py:1183, in SoundFile._open(self, file, mode_int, closefd)
#    1182     raise TypeError("Invalid file: {0!r}".format(self.name))
# -> 1183 _error_check(_snd.sf_error(file_ptr),
#    1184              "Error opening {0!r}: ".format(self.name))
#    1185 if mode_int == _snd.SFM_WRITE:
#    1186     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1187     # when opening a named pipe in SFM_WRITE mode.
#    1188     # See http://github.com/erikd/libsndfile/issues/77.
#
# File ~\.conda\envs\myenv\lib\site-packages\soundfile.py:1357, in _error_check(err, prefix)
#    1356 err_str = _snd.sf_error_number(err)
# -> 1357 raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#
# RuntimeError: Error opening 'D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/savee/AudioData/JE/h08.wav': System error.
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Input In [29], in <cell line: 15>()
#       1 #for i in range(5):
#       2 #    with sr.Microphone() as source:
#       3 #        print("Say something!")
#    (...)
#      11 #plt.title('Waveplot - Male Neutral')
#      12 #plt.show()
# ---> 15 x_audio = get_features('D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/savee/AudioData/JE/h08.wav')
#      16 x_audio = scaler.transform(x_audio)
#      17 x_audio = np.expand_dims(x_audio, axis=2)
#
# Input In [10], in get_features(path)
#      26 def get_features(path):
#      27     # duration and offset are used to take care of the no audio in start and the ending of each audio files as seen above.
# ---> 28     data, sample_rate = librosa.load(path)
#      30     # without augmentation
#      31     res1 = extract_features(data)
#
# File ~\.conda\envs\myenv\lib\site-packages\librosa\util\decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File ~\.conda\envs\myenv\lib\site-packages\librosa\core\audio.py:170, in load(path, sr, mono, offset, duration, dtype, res_type)
#     168 if isinstance(path, (str, pathlib.PurePath)):
#     169     warnings.warn("PySoundFile failed. Trying audioread instead.", stacklevel=2)
# --> 170     y, sr_native = __audioread_load(path, offset, duration, dtype)
#     171 else:
#     172     raise exc
#
# File ~\.conda\envs\myenv\lib\site-packages\librosa\core\audio.py:226, in __audioread_load(path, offset, duration, dtype)
#     223     reader = path
#     224 else:
#     225     # If the input was not an audioread object, try to open it
# --> 226     reader = audioread.audio_open(path)
#     228 with reader as input_file:
#     229     sr_native = input_file.samplerate
#
# File ~\.conda\envs\myenv\lib\site-packages\audioread\__init__.py:111, in audio_open(path, backends)
#     109 for BackendClass in backends:
#     110     try:
# --> 111         return BackendClass(path)
#     112     except DecodeError:
#     113         pass
#
# File ~\.conda\envs\myenv\lib\site-packages\audioread\rawread.py:62, in RawAudioFile.__init__(self, filename)
#      61 def __init__(self, filename):
# ---> 62     self._fh = open(filename, 'rb')
#      64     try:
#      65         self._file = aifc.open(self._fh)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/savee/AudioData/JE/h08.wav'
