# %%
import pandas as pd
import numpy as np
import os
import sys
from tqdm.notebook import tqdm, trange

# librosa is a Python library for analyzing audio and music. It will be used to extract the data from the audio files
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from joblib import dump, load

# to play the audio files
from IPython.display import Audio

import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# # Data Preparation

# %%
# Paths for data.
Ravdess = "D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/Ravdess/"
Crema = "D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/CREMA-D/AudioWAV/"
Tess = "D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS/"
Savee = "D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/savee/AudioData/"

# %%
ravdess_directory_list = os.listdir(Ravdess)

file_emotion = []
file_path = []
for dir in ravdess_directory_list:
    # as their are 20 different actors in our previous directory we need to extract files for each actor.
    actor = os.listdir(Ravdess + dir)
    for file in actor:
        part = file.split('.')[0]
        part = part.split('-')
        # third part in each file represents the emotion associated to that file.
        file_emotion.append(int(part[2]))
        file_path.append(Ravdess + dir + '/' + file)
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Ravdess_df = pd.concat([emotion_df, path_df], axis=1)

# changing integers to actual emotions.
Ravdess_df.Emotions.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
Ravdess_df.head()
# Out:
#   Emotions                                               Path
# 0  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 1  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 2  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 3  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 4     calm  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...

# %%
crema_directory_list = os.listdir(Crema)

file_emotion = []
file_path = []

for file in crema_directory_list:
    # storing file paths
    file_path.append(Crema + file)
    # storing file emotions
    part=file.split('_')
    if part[2] == 'SAD':
        file_emotion.append('sad')
    elif part[2] == 'ANG':
        file_emotion.append('angry')
    elif part[2] == 'DIS':
        file_emotion.append('disgust')
    elif part[2] == 'FEA':
        file_emotion.append('fear')
    elif part[2] == 'HAP':
        file_emotion.append('happy')
    elif part[2] == 'NEU':
        file_emotion.append('neutral')
    else:
        file_emotion.append('Unknown')
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Crema_df = pd.concat([emotion_df, path_df], axis=1)
Crema_df.head()
# Out:
#   Emotions                                               Path
# 0    angry  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 1  disgust  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 2     fear  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 3    happy  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 4  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...

# %%
tess_directory_list = os.listdir(Tess)

file_emotion = []
file_path = []

for file in tess_directory_list:
    part = file.split('.')[0]
    part = part.split('_')[2]
    if part=='ps':
        file_emotion.append('surprise')
    else:
        file_emotion.append(part)
    file_path.append(Tess + '/' + file)
    print(Tess + '/' + file)
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Tess_df = pd.concat([emotion_df, path_df], axis=1)
Tess_df.head()
# Out:
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_back_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_back_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_back_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_back_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_back_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_back_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_back_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bar_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bar_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bar_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bar_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bar_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bar_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bar_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_base_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_base_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_base_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_base_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_base_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_base_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_base_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bath_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bath_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bath_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bath_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bath_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bath_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bath_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bean_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bean_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bean_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bean_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bean_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bean_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bean_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_beg_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_beg_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_beg_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_beg_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_beg_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_beg_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_beg_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bite_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bite_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bite_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bite_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bite_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bite_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bite_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_boat_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_boat_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_boat_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_boat_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_boat_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_boat_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_boat_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bone_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bone_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bone_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bone_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bone_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bone_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bone_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_book_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_book_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_book_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_book_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_book_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_book_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_book_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bought_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bought_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bought_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bought_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bought_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bought_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_bought_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_burn_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_burn_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_burn_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_burn_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_burn_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_burn_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_burn_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cab_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cab_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cab_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cab_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cab_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cab_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cab_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_calm_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_calm_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_calm_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_calm_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_calm_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_calm_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_calm_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_came_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_came_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_came_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_came_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_came_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_came_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_came_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cause_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cause_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cause_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cause_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cause_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cause_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cause_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chain_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chain_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chain_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chain_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chain_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chain_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chain_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chair_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chair_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chair_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chair_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chair_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chair_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chair_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chalk_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chalk_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chalk_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chalk_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chalk_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chalk_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chalk_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chat_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chat_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chat_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chat_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chat_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chat_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chat_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_check_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_check_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_check_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_check_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_check_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_check_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_check_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cheek_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cheek_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cheek_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cheek_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cheek_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cheek_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cheek_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chief_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chief_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chief_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chief_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chief_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chief_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_chief_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_choice_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_choice_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_choice_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_choice_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_choice_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_choice_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_choice_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cool_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cool_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cool_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cool_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cool_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cool_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_cool_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dab_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dab_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dab_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dab_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dab_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dab_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dab_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_date_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_date_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_date_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_date_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_date_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_date_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_date_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dead_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dead_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dead_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dead_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dead_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dead_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dead_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_death_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_death_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_death_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_death_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_death_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_death_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_death_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_deep_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_deep_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_deep_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_deep_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_deep_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_deep_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_deep_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dime_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dime_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dime_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dime_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dime_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dime_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dime_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dip_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dip_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dip_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dip_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dip_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dip_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dip_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_ditch_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_ditch_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_ditch_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_ditch_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_ditch_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_ditch_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_ditch_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dodge_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dodge_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dodge_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dodge_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dodge_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dodge_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dodge_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dog_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dog_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dog_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dog_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dog_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dog_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_dog_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_doll_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_doll_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_doll_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_doll_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_doll_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_doll_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_doll_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_door_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_door_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_door_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_door_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_door_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_door_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_door_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fail_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fail_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fail_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fail_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fail_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fail_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fail_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fall_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fall_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fall_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fall_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fall_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fall_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fall_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_far_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_far_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_far_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_far_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_far_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_far_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_far_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fat_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fat_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fat_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fat_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fat_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fat_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fat_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fit_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fit_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fit_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fit_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fit_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fit_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_fit_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_five_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_five_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_five_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_five_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_five_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_five_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_five_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_food_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_food_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_food_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_food_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_food_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_food_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_food_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gap_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gap_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gap_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gap_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gap_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gap_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gap_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gas_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gas_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gas_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gas_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gas_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gas_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gas_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gaze_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gaze_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gaze_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gaze_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gaze_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gaze_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gaze_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_germ_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_germ_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_germ_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_germ_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_germ_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_germ_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_germ_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_get_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_get_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_get_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_get_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_get_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_get_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_get_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gin_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gin_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gin_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gin_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gin_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gin_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gin_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_goal_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_goal_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_goal_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_goal_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_goal_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_goal_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_goal_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_good_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_good_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_good_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_good_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_good_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_good_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_good_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_goose_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_goose_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_goose_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_goose_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_goose_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_goose_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_goose_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gun_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gun_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gun_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gun_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gun_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gun_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_gun_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_half_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_half_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_half_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_half_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_half_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_half_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_half_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hall_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hall_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hall_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hall_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hall_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hall_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hall_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hash_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hash_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hash_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hash_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hash_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hash_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hash_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hate_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hate_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hate_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hate_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hate_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hate_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hate_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_have_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_have_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_have_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_have_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_have_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_have_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_have_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_haze_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_haze_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_haze_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_haze_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_haze_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_haze_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_haze_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hire_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hire_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hire_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hire_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hire_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hire_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hire_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hit_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hit_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hit_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hit_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hit_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hit_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hit_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hole_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hole_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hole_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hole_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hole_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hole_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hole_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_home_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_home_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_home_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_home_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_home_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_home_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_home_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hurl_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hurl_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hurl_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hurl_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hurl_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hurl_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hurl_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hush_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hush_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hush_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hush_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hush_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hush_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_hush_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jail_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jail_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jail_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jail_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jail_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jail_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jail_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jar_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jar_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jar_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jar_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jar_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jar_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jar_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_join_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_join_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_join_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_join_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_join_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_join_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_join_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_judge_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_judge_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_judge_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_judge_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_judge_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_judge_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_judge_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jug_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jug_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jug_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jug_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jug_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jug_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_jug_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_juice_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_juice_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_juice_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//OAF_juice_happy.wav
# ...
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_ton_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_tool_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_tool_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_tool_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_tool_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_tool_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_tool_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_tool_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_tough_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_tough_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_tough_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_tough_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_tough_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_tough_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_tough_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_turn_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_turn_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_turn_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_turn_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_turn_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_turn_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_turn_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_vine_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_vine_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_vine_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_vine_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_vine_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_vine_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_vine_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_voice_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_voice_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_voice_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_voice_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_voice_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_voice_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_voice_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_void_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_void_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_void_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_void_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_void_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_void_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_void_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_vote_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_vote_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_vote_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_vote_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_vote_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_vote_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_vote_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wag_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wag_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wag_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wag_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wag_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wag_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wag_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_walk_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_walk_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_walk_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_walk_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_walk_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_walk_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_walk_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wash_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wash_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wash_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wash_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wash_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wash_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wash_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_week_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_week_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_week_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_week_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_week_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_week_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_week_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wheat_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wheat_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wheat_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wheat_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wheat_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wheat_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wheat_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_when_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_when_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_when_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_when_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_when_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_when_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_when_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_which_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_which_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_which_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_which_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_which_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_which_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_which_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_whip_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_whip_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_whip_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_whip_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_whip_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_whip_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_whip_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_white_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_white_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_white_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_white_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_white_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_white_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_white_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wife_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wife_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wife_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wife_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wife_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wife_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wife_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wire_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wire_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wire_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wire_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wire_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wire_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_wire_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_witch_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_witch_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_witch_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_witch_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_witch_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_witch_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_witch_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_yearn_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_yearn_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_yearn_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_yearn_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_yearn_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_yearn_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_yearn_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_yes_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_yes_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_yes_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_yes_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_yes_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_yes_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_yes_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_young_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_young_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_young_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_young_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_young_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_young_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_young_sad.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_youth_angry.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_youth_disgust.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_youth_fear.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_youth_happy.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_youth_neutral.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_youth_ps.wav
# D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/TESS//YAF_youth_sad.wav
#   Emotions                                               Path
# 0    angry  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 1  disgust  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 2     fear  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 3    happy  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 4  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...

# %%
savee_directory_list = os.listdir(Savee)

file_emotion = []
file_path = []

for dir in savee_directory_list:
    directories = os.listdir(Savee + dir)
    for file in directories:
        file_path.append(Savee + dir + '/' + file)
        #part = file.split('_')[1]
        ele = file[:-6]
        if ele=='a':
            file_emotion.append('angry')
        elif ele=='d':
            file_emotion.append('disgust')
        elif ele=='f':
            file_emotion.append('fear')
        elif ele=='h':
            file_emotion.append('happy')
        elif ele=='n':
            file_emotion.append('neutral')
        elif ele=='sa':
            file_emotion.append('sad')
        else:
            file_emotion.append('surprise')
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Savee_df = pd.concat([emotion_df, path_df], axis=1)
Savee_df.head()
# Out:
#   Emotions                                               Path
# 0    angry  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 1    angry  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 2    angry  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 3    angry  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 4    angry  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...

# %%
# creating Dataframe using all the 4 dataframes we created so far.
data_path = pd.concat([Ravdess_df, Savee_df, Tess_df], axis = 0) #,Crema_df
data_path.to_csv("data_path.csv",index=False)
data_path.head()
# Out:
#   Emotions                                               Path
# 0  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 1  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 2  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 3  neutral  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...
# 4     calm  D:/Schmiede/Coding/IIS_Seminar/emotion-detecti...

# %% [markdown]
# # Data Visualisation and Exploration

# %%
plt.title('Count of Emotions', size=16)
sns.countplot(data_path.Emotions)
plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
def create_waveplot(data, sr, e):
    plt.figure(figsize=(10, 3))
    plt.title('Waveplot for audio with {} emotion'.format(e), size=15)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def create_spectrogram(data, sr, e):
    # stft function converts the data into short term fourier transform
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(12, 3))
    plt.title('Spectrogram for audio with {} emotion'.format(e), size=15)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')   
    #librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar()

# %% [markdown]
# # Data Augmentation

# %%
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate)

def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)

def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)

# taking any example and checking for techniques.
path = np.array(data_path.Path)[1]
data, sample_rate = librosa.load(path)

# %% [markdown]
# # Feature Extraction

# %%
def extract_features(data):
    # ZCR
    result = np.array([])
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    result=np.hstack((result, zcr)) # stacking horizontally

    # Chroma_stft
    stft = np.abs(librosa.stft(data))
    chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
    result = np.hstack((result, chroma_stft)) # stacking horizontally

    # MFCC
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mfcc)) # stacking horizontally

    # Root Mean Square Value
    rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
    result = np.hstack((result, rms)) # stacking horizontally

    # MelSpectogram
    mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mel)) # stacking horizontally
    
    return result

def get_features(path):
    # duration and offset are used to take care of the no audio in start and the ending of each audio files as seen above.
    data, sample_rate = librosa.load(path)
    
    # without augmentation
    res1 = extract_features(data)
    result = np.array(res1)
    
    # data with noise
    noise_data = noise(data)
    res2 = extract_features(noise_data)
    result = np.vstack((result, res2)) # stacking vertically
    
    # data with stretching and pitching
    new_data = stretch(data)
    data_stretch_pitch = pitch(new_data, sample_rate)
    res3 = extract_features(data_stretch_pitch)
    result = np.vstack((result, res3)) # stacking vertically
    
    return result

# %%
X, Y = [], []
for path, emotion in tqdm(zip(data_path.Path, data_path.Emotions), total=len(data_path.Path)):
    if emotion in ['angry','happy','fear','sad']:      #filter emotions
        feature = get_features(path)
        for ele in feature:
            X.append(ele)
            # appending emotion 3 times as we have made 3 augmentation techniques on each audio file.
            Y.append(emotion)

# %%
len(X), len(Y), data_path.Path.shape

# %%
Features = pd.DataFrame(X)
Features['labels'] = Y
Features.to_csv('features_small.csv', index=False)
Features.head()

# %% [markdown]
# # Data Preparation

# %%
Features = pd.read_csv('features_small.csv')
X = Features.iloc[: ,:-1].values
Y = Features['labels'].values

# %%
# As this is a multiclass classification problem onehotencoding our Y.
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
# splitting data
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape

# %%
# scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape

#dump(scaler, 'std_scaler.bin', compress=True)

# %%
# making our data compatible to model.
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape

# %% [markdown]
# # Modelling

# %%
model = Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=4, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()

# %%
########### only to test settings!########################
def cnn2(X_train, y_train):
    model = Sequential()
    model.add(Conv1D(256, 4, padding='same', input_shape=(X_train.shape[1],1)))  # X_train.shape[1] = No. of Columns
    model.add(Activation('relu'))
    model.add(Conv1D(256, 4, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(8)))
    model.add(Conv1D(128, 4, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 4, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 4, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(128, 4, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    model.add(MaxPooling1D(pool_size=(8)))
    model.add(Conv1D(64, 4, padding='same'))
    model.add(Activation('relu'))
    model.add(Conv1D(64, 4, padding='same'))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(y_train.shape[1])) # Target class number
    model.add(Activation('softmax'))
    model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])
    return model

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)
history=model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), callbacks=[rlrp])

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(50)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()

# %%
# predicting on test data.
pred_test = model.predict(x_test)

y_pred = encoder.inverse_transform(pred_test)
y_test = encoder.inverse_transform(y_test)

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
model.save('SER_model_without_CREMA.h5')

# %% [markdown]
# --------------------------------------------------------------------------------------
# Use the part below to test the trained model.

# %%
#PREPARE
import speech_recognition as sr
import librosa as lb
from joblib import dump, load
scaler = load('std_scaler.bin')  #load pretrained SciKit StandardScaler
r = sr.Recognizer()
model = keras.models.load_model('SER_model_without_CREMA.h5')

# %%
#for i in range(5):
#    with sr.Microphone() as source:
#        print("Say something!")
#        audio = r.listen(source)
#    with open("microphone-results.wav", "wb") as f:
#        f.write(audio.get_wav_data())
    
#X, sample_rate = lb.load('D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/Ravdess/Actor_03/03-01-01-01-01-01-03.wav')
#plt.figure(figsize=(8, 4))
#lb.display.waveshow(X, sr=sample_rate)
#plt.title('Waveplot - Male Neutral')
#plt.show()


x_audio = get_features('D:/Schmiede/Coding/IIS_Seminar/emotion-detection-and-reaction/SER/data/savee/AudioData/JE/h08.wav')
x_audio = scaler.transform(x_audio)
x_audio = np.expand_dims(x_audio, axis=2)
pred = model.predict(x_audio)
#pred = encoder.inverse_transform(pred)
#print(np.argmax(pred[0]))
j=[]
for i in range(3):
    j.append(np.argmax(pred[i]))
counts = np.bincount(j)
print(np.argmax(counts))
#0:angry, 1:fear, 2:happy, 3:sad
# Out:
# 2
